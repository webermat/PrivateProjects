# %%
import numpy as np
import pandas as pd
from statistics import mean 

import seaborn as sns
import scikitplot as skplt
import matplotlib.pyplot as plt


from sklearn.pipeline import Pipeline
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV

# %%
df=pd.read_csv("../data/card_transactions.csv")
df.head()
# Out:
#         customer_id  balance_account  purchases_amount  paid_advance  \
# 0  tGEg8fT2eCgVxdwS         9.298409            107.60      0.000000
# 1  stEDu20sSKOXomjg        52.666422            150.30      0.000000
# 2  CEB2blrN3b88GsRe      1360.795674              0.00    462.861443
# 3  0N0eBl8ySaZThxKE      2021.641161            363.18      0.000000
# 4  6NLauoHUwtwOv4Wy        22.322374             95.00   1162.045833
#
#    full_purchases  balance_frequency_update  installments  \
# 0            0.00                  0.909091         107.6
# 1            0.00                  1.000000         150.3
# 2            0.00                  1.000000           0.0
# 3          363.18                  1.000000           0.0
# 4           95.00                  0.363636           0.0
#
#    purchases_frequency  full_purchases_frequency  \
# 0             0.909091                  0.000000
# 1             1.000000                  0.000000
# 2             0.000000                  0.000000
# 3             1.000000                  1.000000
# 4             0.083333                  0.083333
#
#    purchases_installments_frequency  cash_advance_frequency  nr_cash_advances  \
# 0                          0.818182                0.000000                 0
# 1                          0.833333                0.000000                 0
# 2                          0.000000                0.272727                 6
# 3                          0.000000                0.000000                 0
# 4                          0.000000                0.166667                 3
#
#    nr_purchases  credit_limit  fixed_rate_period     payments  min_payments  \
# 0            10        1000.0                 11    89.868853     89.711672
# 1             6        1000.0                  6    54.722514     82.955180
# 2             0        1500.0                 11   303.031979    443.781316
# 3            13        2000.0                 12   704.240770    795.859808
# 4             1        2500.0                 12  4094.261427     40.142262
#
#    full_payment_prc
# 0          0.428571
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000

# %%
print(df.shape,len(df["customer_id"].unique()),df.dtypes,df.isna().sum())
# Out:
# (8500, 18) 8500 customer_id                          object
# balance_account                     float64
# purchases_amount                    float64
# paid_advance                        float64
# full_purchases                      float64
# balance_frequency_update            float64
# installments                        float64
# purchases_frequency                 float64
# full_purchases_frequency            float64
# purchases_installments_frequency    float64
# cash_advance_frequency              float64
# nr_cash_advances                      int64
# nr_purchases                          int64
# credit_limit                        float64
# fixed_rate_period                     int64
# payments                            float64
# min_payments                        float64
# full_payment_prc                    float64
# dtype: object customer_id                           0
# balance_account                       0
# purchases_amount                      0
# paid_advance                          0
# full_purchases                        0
# balance_frequency_update              0
# installments                          0
# purchases_frequency                   0
# full_purchases_frequency              0
# purchases_installments_frequency      0
# cash_advance_frequency                0
# nr_cash_advances                      0
# nr_purchases                          0
# credit_limit                          1
# fixed_rate_period                     0
# payments                              0
# min_payments                        298
# full_payment_prc                      0
# dtype: int64

# %% [markdown]
# Just some overall stats: 8500 customers, with 18 features each, indeed no duplicates, aka unique customer_id length is the same than the overall dataframe dimensions, min payment has quite a couple of NAs, so let's deal with that via imputing data maybe later on.

# %%
#sns.heatmap(df.drop(columns=["customer_id"]).corr(),anotate=True)
df.drop(columns=["customer_id"]).corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T
#T_da248eda_0a00_11eb_83bc_acde48001122row9_col13,#T_da248eda_0a00_11eb_83bc_acde48001122row16_col0,#T_da248eda_0a00_11eb_83bc_acde48001122row16_col4,#T_da248eda_0a00_11eb_83bc_acde48001122row16_col12,#T_da248eda_0a00_11eb_83bc_acde48001122row16_col15{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col2,#T_da248eda_0a00_11eb_83bc_acde48001122row5_col9,#T_da248eda_0a00_11eb_83bc_acde48001122row11_col9,#T_da248eda_0a00_11eb_83bc_acde48001122row13_col3,#T_da248eda_0a00_11eb_83bc_acde48001122row13_col9,#T_da248eda_0a00_11eb_83bc_acde48001122row15_col16{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col3{
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col4,#T_da248eda_0a00_11eb_83bc_acde48001122row9_col15,#T_da248eda_0a00_11eb_83bc_acde48001122row14_col13,#T_da248eda_0a00_11eb_83bc_acde48001122row15_col4{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col5,#T_da248eda_0a00_11eb_83bc_acde48001122row2_col9,#T_da248eda_0a00_11eb_83bc_acde48001122row11_col1{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col6,#T_da248eda_0a00_11eb_83bc_acde48001122row10_col0{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col7,#T_da248eda_0a00_11eb_83bc_acde48001122row3_col14,#T_da248eda_0a00_11eb_83bc_acde48001122row14_col2,#T_da248eda_0a00_11eb_83bc_acde48001122row15_col0{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col8,#T_da248eda_0a00_11eb_83bc_acde48001122row14_col5{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col9,#T_da248eda_0a00_11eb_83bc_acde48001122row14_col4{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col10,#T_da248eda_0a00_11eb_83bc_acde48001122row7_col10,#T_da248eda_0a00_11eb_83bc_acde48001122row10_col12,#T_da248eda_0a00_11eb_83bc_acde48001122row10_col16{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col11{
#             background-color:  #f6a385;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col12,#T_da248eda_0a00_11eb_83bc_acde48001122row12_col6,#T_da248eda_0a00_11eb_83bc_acde48001122row14_col16{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col13,#T_da248eda_0a00_11eb_83bc_acde48001122row5_col13,#T_da248eda_0a00_11eb_83bc_acde48001122row8_col0,#T_da248eda_0a00_11eb_83bc_acde48001122row8_col3,#T_da248eda_0a00_11eb_83bc_acde48001122row13_col5{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col15,#T_da248eda_0a00_11eb_83bc_acde48001122row11_col15{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_da248eda_0a00_11eb_83bc_acde48001122row1_col16,#T_da248eda_0a00_11eb_83bc_acde48001122row5_col16,#T_da248eda_0a00_11eb_83bc_acde48001122row14_col10{

# %%
sns.pairplot(df)

# %%
sc = StandardScaler()


df_scaled= pd.DataFrame(sc.fit_transform(df.drop(columns=["customer_id"])), columns = df.drop(columns=["customer_id"]).columns)
plt.figure(figsize=(16,14))
sns.boxplot(data = df_scaled)
plt.xticks(rotation=65, horizontalalignment='right')

# %% [markdown]
# # KNN Imputation to remove NAs

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# %%
### Numerical columns
num_feat = df.iloc[:, list(np.where(df.dtypes != "object")[0])]
num_col_name = df.iloc[:, list(np.where(df.dtypes != "object")[0])].columns

### KNN Imputer
imputer = KNNImputer(n_neighbors=5, weights="distance")
imputed = imputer.fit_transform(num_feat)

### Recreate Dataframe
df_no_na = pd.DataFrame(imputed, columns=num_col_name)
df_result = pd.concat([pd.DataFrame(df.iloc[:,0]), df_no_na], axis=1, sort=False)

df_result.isna().sum().sum()
# Out:
# 0
